# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv("zillow_county_data.csv")

# %%
df.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     County        CA    CA
# 1       139         1         Cook County     County        IL    IL
# 2      1090         2       Harris County     County        TX    TX
# 3      2402         3     Maricopa County     County        AZ    AZ
# 4      2841         4    San Diego County     County        CA    CA
#
#                               Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim              6                 37
# 1          Chicago-Naperville-Elgin             17                 31
# 2  Houston-The Woodlands-Sugar Land             48                201
# 3           Phoenix-Mesa-Scottsdale              4                 13
# 4                San Diego-Carlsbad              6                 73
#
#    1/31/1996  ...  5/31/2020  6/30/2020  7/31/2020  8/31/2020  9/30/2020  \
# ...

# %%
njdf = df.loc[df["State"]=="NJ"]

# %%
njdf.head()
# Out:
#     RegionID  SizeRank        RegionName RegionType StateName State  \
# 53       874        53     Bergen County     County        NJ    NJ
# 63      2802        63  Middlesex County     County        NJ    NJ
# 72       504        72      Essex County     County        NJ    NJ
# 93      1106        93     Hudson County     County        NJ    NJ
# 94      2441        94   Monmouth County     County        NJ    NJ
#
#                           Metro  StateCodeFIPS  MunicipalCodeFIPS  1/31/1996  \
# 53  New York-Newark-Jersey City             34                  3   217372.0
# 63  New York-Newark-Jersey City             34                 23   161932.0
# 72  New York-Newark-Jersey City             34                 13   171010.0
# 93  New York-Newark-Jersey City             34                 17   151544.0
# 94  New York-Newark-Jersey City             34                 25   184373.0
#
#     ...  5/31/2020  6/30/2020  7/31/2020  8/31/2020  9/30/2020  10/31/2020  \
# ...

# %%
njdf.drop(columns = ['RegionID','SizeRank','RegionType','StateName','State','Metro','StateCodeFIPS','MunicipalCodeFIPS'],inplace = True)
# Out:
# C:\Users\ninam\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
njdf.head()
# Out:
#           RegionName  1/31/1996  2/29/1996  3/31/1996  4/30/1996  5/31/1996  \
# 53     Bergen County   217372.0   216879.0   216519.0   215786.0   215181.0
# 63  Middlesex County   161932.0   161446.0   161171.0   160598.0   160242.0
# 72      Essex County   171010.0   170405.0   169943.0   168988.0   168298.0
# 93     Hudson County   151544.0   151161.0   151025.0   150627.0   150348.0
# 94   Monmouth County   184373.0   184071.0   183848.0   183472.0   183294.0
#
#     6/30/1996  7/31/1996  8/31/1996  9/30/1996  ...  5/31/2020  6/30/2020  \
# 53   214704.0   214346.0   214179.0   214131.0  ...     503727     506563
# 63   159869.0   159646.0   159455.0   159407.0  ...     354509     355771
# 72   167733.0   167360.0   167125.0   166892.0  ...     422450     426052
# 93   149908.0   149675.0   149579.0   149722.0  ...     488523     490095
# 94   183225.0   183264.0   183501.0   183736.0  ...     448948     451137
#
# ...

# %%
nj_data = njdf.set_index('RegionName').T

# %%
nj_data.head()
# Out:
# RegionName  Bergen County  Middlesex County  Essex County  Hudson County  \
# 1/31/1996        217372.0          161932.0      171010.0       151544.0
# 2/29/1996        216879.0          161446.0      170405.0       151161.0
# 3/31/1996        216519.0          161171.0      169943.0       151025.0
# 4/30/1996        215786.0          160598.0      168988.0       150627.0
# 5/31/1996        215181.0          160242.0      168298.0       150348.0
#
# RegionName  Monmouth County  Ocean County  Union County  Camden County  \
# 1/31/1996          184373.0      135875.0      182432.0       106455.0
# 2/29/1996          184071.0      135771.0      182039.0       106666.0
# 3/31/1996          183848.0      135664.0      181689.0       106720.0
# 4/30/1996          183472.0      135473.0      181080.0       106928.0
# 5/31/1996          183294.0      135265.0      180555.0       106945.0
#
# RegionName  Passaic County  Morris County  ...  Mercer County  \
# ...

# %%
atlantic_df = pd.DataFrame(nj_data["Atlantic County"])
atlantic_df.reset_index(inplace = True)
atlantic_df.columns = ["Date","Price"]
atlantic_df.head()
# Out:
#         Date     Price
# 0  1/31/1996  109980.0
# 1  2/29/1996  109678.0
# 2  3/31/1996  109483.0
# 3  4/30/1996  109162.0
# 4  5/31/1996  109007.0

# %%
# atlantic_df['Date'] = pd.to_datetime(atlantic_df['Date'], format='%m/%d/%Y')
atlantic_df['year'] = pd.DatetimeIndex(atlantic_df['Date']).year

atlantic_df.head()
# Out:
#         Date     Price  year
# 0 1996-01-31  109980.0  1996
# 1 1996-02-29  109678.0  1996
# 2 1996-03-31  109483.0  1996
# 3 1996-04-30  109162.0  1996
# 4 1996-05-31  109007.0  1996

# %%
atl_grouped = atlantic_df.groupby(atlantic_df['year'],as_index=False).mean()
atl_grouped.round(2)
atl_grouped['County']="Atlantic"
atl_grouped.head()
# Out:
#    year          Price    County
# 0  1996  108995.083333  Atlantic
# 1  1997  111600.333333  Atlantic
# 2  1998  115382.333333  Atlantic
# 3  1999  120679.000000  Atlantic
# 4  2000  128581.333333  Atlantic

# %%
bergen_df = pd.DataFrame(nj_data["Bergen County"])
bergen_df.reset_index(inplace = True)
bergen_df.columns = ["Date","Price"]
bergen_df['year'] = pd.DatetimeIndex(bergen_df['Date']).year
ber_grouped = atlantic_df.groupby(bergen_df['year'],as_index=False).mean()
ber_grouped.round(2)
ber_grouped['County']="Bergen"
ber_grouped.head()
# Out:
#            Price  year  County
# 0  108995.083333  1996  Bergen
# 1  111600.333333  1997  Bergen
# 2  115382.333333  1998  Bergen
# 3  120679.000000  1999  Bergen
# 4  128581.333333  2000  Bergen

# %%
camden_df = nj_data["Camden County"]
camden_df = pd.DataFrame(nj_data["Camden County"])
camden_df.reset_index(inplace = True)
camden_df.columns = ["Date","Price"]
camden_df['year'] = pd.DatetimeIndex(bergen_df['Date']).year
cam_grouped = atlantic_df.groupby(camden_df['year'],as_index=False).mean()
cam_grouped.round(2)
cam_grouped['County']="Camden"
cam_grouped.head()
# Out:
#            Price  year  County
# 0  108995.083333  1996  Camden
# 1  111600.333333  1997  Camden
# 2  115382.333333  1998  Camden
# 3  120679.000000  1999  Camden
# 4  128581.333333  2000  Camden

# %%
df1 = pd.concat([atl_grouped,ber_grouped,cam_grouped],ignore_index = True)

# %%
df1.head(-20)
# Out:
#     year          Price    County
# 0   1996  108995.083333  Atlantic
# 1   1997  111600.333333  Atlantic
# 2   1998  115382.333333  Atlantic
# 3   1999  120679.000000  Atlantic
# 4   2000  128581.333333  Atlantic
# 5   2001  137365.916667  Atlantic
# 6   2002  151304.166667  Atlantic
# 7   2003  176166.750000  Atlantic
# 8   2004  209567.750000  Atlantic
# 9   2005  252320.000000  Atlantic
# 10  2006  290632.750000  Atlantic
# 11  2007  291331.666667  Atlantic
# 12  2008  267769.833333  Atlantic
# 13  2009  233581.916667  Atlantic
# 14  2010  221230.750000  Atlantic
# 15  2011  205974.833333  Atlantic
# 16  2012  194958.583333  Atlantic
# 17  2013  191150.750000  Atlantic
# 18  2014  194470.000000  Atlantic
# 19  2015  186052.250000  Atlantic
# 20  2016  175862.000000  Atlantic
# 21  2017  176391.250000  Atlantic
# 22  2018  185926.083333  Atlantic
# 23  2019  196067.416667  Atlantic
# 24  2020  209139.500000  Atlantic
# 25  2021  229061.000000  Atlantic
# ...
