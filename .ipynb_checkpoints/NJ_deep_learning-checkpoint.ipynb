# %%
# Dependencies
import pandas as pd
import numpy as np
import os

# %%
#  import csv
df = pd.read_csv('final_data.csv')
df.head()
# Out:
#        county  year  violent_crime  murder  rape  robbery  aggravated_assault  \
# 0    Atlantic  2019              0       0     0        0                   0
# 1      Bergen  2019              2       0     2        0                   0
# 2  Burlington  2019              0       0     0        0                   0
# 3      Camden  2019              2       0     0        0                   2
# 4    Cape May  2019              0       0     0        0                   0
#
#    property_crime  burglary  larceny_theft  ...    frm_15  points_15  \
# 0               0         0              0  ...  3.391731      0.475
# 1              46         2             44  ...  3.391731      0.475
# 2               0         0              0  ...  3.391731      0.475
# 3              44         4             38  ...  3.391731      0.475
# 4               0         0              0  ...  3.391731      0.475
#
#    median_hh_income  median_hh_inc_moe  poverty_count  poverty_count_moe  \
# 0             62678               2822          29057               4251
# 1            107971               3025          52980               7662
# 2             88443               3233          24961               4374
# 3             73168               2374          53641               7048
# 4             66565               4753           8853               1981
#
#    poverty_rate  poverty_rate_moe  county_fips      price
# 0           1.6              11.3            1  196067.42
# 1           0.8               5.7            3  494018.42
# 2           1.0               5.7            5  238593.67
# 3           1.4              10.7            7  181980.75
# 4           2.2               9.8            9  389294.58
#
# [5 rows x 24 columns]

# %%
#  drop nulls
df.dropna(how='any', inplace = True)
# df.dtypes

# %%
# Set features. This will also be used as x values.
X = df.drop(['county', 'county_fips'], axis=1)
y = df["county"]
print(X.shape, y.shape)
# Out:
# (164, 22) (164,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
# Split data into training and testing groups and scale data 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train,21)
y_test_categorical = to_categorical(encoded_y_test,21)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the model
deep_model = Sequential()
# Add first layer
deep_model.add(Dense(units=50, activation='relu', input_dim=22))
# Add second layer (deep)
deep_model.add(Dense(units=50, activation='relu'))
# Add third layer (deep)
deep_model.add(Dense(units=50, activation='relu'))
#  Add output layer
deep_model.add(Dense(units=21, activation='softmax'))

# %%
#  model summary
deep_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                1150
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_3 (Dense)              (None, 21)                1071
# =================================================================
# Total params: 7,321
# Trainable params: 7,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and fit the model
deep_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Fit the model to the training data
deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2)
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 3.0470 - accuracy: 0.0163
# Epoch 2/100
# 4/4 - 0s - loss: 3.0264 - accuracy: 0.0325
# Epoch 3/100
# 4/4 - 0s - loss: 3.0118 - accuracy: 0.0894
# Epoch 4/100
# 4/4 - 0s - loss: 2.9972 - accuracy: 0.1382
# Epoch 5/100
# 4/4 - 0s - loss: 2.9839 - accuracy: 0.1301
# Epoch 6/100
# 4/4 - 0s - loss: 2.9711 - accuracy: 0.1301
# Epoch 7/100
# 4/4 - 0s - loss: 2.9557 - accuracy: 0.1220
# Epoch 8/100
# 4/4 - 0s - loss: 2.9369 - accuracy: 0.1301
# Epoch 9/100
# 4/4 - 0s - loss: 2.9190 - accuracy: 0.1545
# Epoch 10/100
# 4/4 - 0s - loss: 2.8959 - accuracy: 0.1626
# Epoch 11/100
# 4/4 - 0s - loss: 2.8726 - accuracy: 0.1707
# Epoch 12/100
# 4/4 - 0s - loss: 2.8430 - accuracy: 0.1789
# Epoch 13/100
# 4/4 - 0s - loss: 2.8091 - accuracy: 0.1707
# Epoch 14/100
# 4/4 - 0s - loss: 2.7688 - accuracy: 0.1789
# Epoch 15/100
# 4/4 - 0s - loss: 2.7300 - accuracy: 0.1951
# Epoch 16/100
# 4/4 - 0s - loss: 2.6832 - accuracy: 0.2114
# Epoch 17/100
# 4/4 - 0s - loss: 2.6296 - accuracy: 0.2276
# Epoch 18/100
# 4/4 - 0s - loss: 2.5728 - accuracy: 0.2439
# Epoch 19/100
# 4/4 - 0s - loss: 2.5127 - accuracy: 0.2683
# Epoch 20/100
# 4/4 - 0s - loss: 2.4469 - accuracy: 0.3008
# Epoch 21/100
# 4/4 - 0s - loss: 2.3826 - accuracy: 0.3415
# Epoch 22/100
# 4/4 - 0s - loss: 2.3136 - accuracy: 0.3415
# Epoch 23/100
# 4/4 - 0s - loss: 2.2401 - accuracy: 0.3496
# Epoch 24/100
# 4/4 - 0s - loss: 2.1685 - accuracy: 0.3984
# Epoch 25/100
# 4/4 - 0s - loss: 2.0970 - accuracy: 0.3984
# Epoch 26/100
# 4/4 - 0s - loss: 2.0199 - accuracy: 0.4390
# Epoch 27/100
# 4/4 - 0s - loss: 1.9477 - accuracy: 0.4472
# Epoch 28/100
# 4/4 - 0s - loss: 1.8737 - accuracy: 0.4878
# Epoch 29/100
# 4/4 - 0s - loss: 1.7994 - accuracy: 0.5203
# Epoch 30/100
# 4/4 - 0s - loss: 1.7287 - accuracy: 0.5528
# Epoch 31/100
# 4/4 - 0s - loss: 1.6498 - accuracy: 0.5691
# Epoch 32/100
# 4/4 - 0s - loss: 1.5849 - accuracy: 0.5772
# Epoch 33/100
# 4/4 - 0s - loss: 1.5154 - accuracy: 0.6260
# Epoch 34/100
# 4/4 - 0s - loss: 1.4415 - accuracy: 0.6585
# Epoch 35/100
# 4/4 - 0s - loss: 1.3787 - accuracy: 0.6504
# Epoch 36/100
# 4/4 - 0s - loss: 1.3151 - accuracy: 0.6667
# Epoch 37/100
# 4/4 - 0s - loss: 1.2568 - accuracy: 0.7073
# Epoch 38/100
# 4/4 - 0s - loss: 1.1937 - accuracy: 0.7480
# Epoch 39/100
# 4/4 - 0s - loss: 1.1379 - accuracy: 0.7886
# Epoch 40/100
# 4/4 - 0s - loss: 1.0842 - accuracy: 0.8049
# Epoch 41/100
# 4/4 - 0s - loss: 1.0317 - accuracy: 0.8130
# Epoch 42/100
# 4/4 - 0s - loss: 0.9843 - accuracy: 0.8293
# Epoch 43/100
# 4/4 - 0s - loss: 0.9424 - accuracy: 0.8293
# Epoch 44/100
# 4/4 - 0s - loss: 0.8934 - accuracy: 0.8780
# Epoch 45/100
# 4/4 - 0s - loss: 0.8529 - accuracy: 0.8618
# Epoch 46/100
# 4/4 - 0s - loss: 0.8151 - accuracy: 0.8780
# Epoch 47/100
# 4/4 - 0s - loss: 0.7775 - accuracy: 0.9024
# Epoch 48/100
# 4/4 - 0s - loss: 0.7394 - accuracy: 0.9106
# Epoch 49/100
# 4/4 - 0s - loss: 0.7080 - accuracy: 0.9187
# Epoch 50/100
# 4/4 - 0s - loss: 0.6758 - accuracy: 0.9106
# Epoch 51/100
# 4/4 - 0s - loss: 0.6461 - accuracy: 0.9187
# Epoch 52/100
# 4/4 - 0s - loss: 0.6188 - accuracy: 0.9268
# Epoch 53/100
# 4/4 - 0s - loss: 0.5915 - accuracy: 0.9512
# Epoch 54/100
# 4/4 - 0s - loss: 0.5632 - accuracy: 0.9512
# Epoch 55/100
# 4/4 - 0s - loss: 0.5396 - accuracy: 0.9675
# Epoch 56/100
# 4/4 - 0s - loss: 0.5171 - accuracy: 0.9593
# Epoch 57/100
# 4/4 - 0s - loss: 0.4948 - accuracy: 0.9756
# Epoch 58/100
# 4/4 - 0s - loss: 0.4733 - accuracy: 0.9837
# Epoch 59/100
# 4/4 - 0s - loss: 0.4543 - accuracy: 0.9837
# Epoch 60/100
# 4/4 - 0s - loss: 0.4341 - accuracy: 0.9675
# Epoch 61/100
# 4/4 - 0s - loss: 0.4166 - accuracy: 0.9837
# Epoch 62/100
# 4/4 - 0s - loss: 0.4005 - accuracy: 0.9837
# Epoch 63/100
# 4/4 - 0s - loss: 0.3862 - accuracy: 0.9919
# Epoch 64/100
# 4/4 - 0s - loss: 0.3663 - accuracy: 0.9837
# Epoch 65/100
# 4/4 - 0s - loss: 0.3538 - accuracy: 0.9756
# Epoch 66/100
# 4/4 - 0s - loss: 0.3395 - accuracy: 0.9837
# Epoch 67/100
# 4/4 - 0s - loss: 0.3255 - accuracy: 0.9919
# Epoch 68/100
# 4/4 - 0s - loss: 0.3149 - accuracy: 0.9837
# Epoch 69/100
# 4/4 - 0s - loss: 0.3007 - accuracy: 0.9756
# Epoch 70/100
# 4/4 - 0s - loss: 0.2889 - accuracy: 0.9919
# Epoch 71/100
# 4/4 - 0s - loss: 0.2777 - accuracy: 0.9919
# Epoch 72/100
# 4/4 - 0s - loss: 0.2650 - accuracy: 0.9919
# Epoch 73/100
# 4/4 - 0s - loss: 0.2597 - accuracy: 0.9919
# Epoch 74/100
# 4/4 - 0s - loss: 0.2463 - accuracy: 0.9919
# Epoch 75/100
# 4/4 - 0s - loss: 0.2387 - accuracy: 0.9919
# Epoch 76/100
# 4/4 - 0s - loss: 0.2319 - accuracy: 0.9919
# Epoch 77/100
# 4/4 - 0s - loss: 0.2233 - accuracy: 1.0000
# Epoch 78/100
# 4/4 - 0s - loss: 0.2147 - accuracy: 1.0000
# Epoch 79/100
# 4/4 - 0s - loss: 0.2064 - accuracy: 1.0000
# Epoch 80/100
# 4/4 - 0s - loss: 0.1998 - accuracy: 0.9919
# Epoch 81/100
# 4/4 - 0s - loss: 0.1953 - accuracy: 0.9919
# Epoch 82/100
# 4/4 - 0s - loss: 0.1845 - accuracy: 1.0000
# Epoch 83/100
# 4/4 - 0s - loss: 0.1774 - accuracy: 1.0000
# Epoch 84/100
# 4/4 - 0s - loss: 0.1711 - accuracy: 1.0000
# Epoch 85/100
# 4/4 - 0s - loss: 0.1652 - accuracy: 1.0000
# Epoch 86/100
# 4/4 - 0s - loss: 0.1592 - accuracy: 1.0000
# Epoch 87/100
# 4/4 - 0s - loss: 0.1542 - accuracy: 1.0000
# Epoch 88/100
# 4/4 - 0s - loss: 0.1486 - accuracy: 1.0000
# Epoch 89/100
# 4/4 - 0s - loss: 0.1432 - accuracy: 1.0000
# Epoch 90/100
# 4/4 - 0s - loss: 0.1389 - accuracy: 1.0000
# Epoch 91/100
# 4/4 - 0s - loss: 0.1348 - accuracy: 1.0000
# Epoch 92/100
# 4/4 - 0s - loss: 0.1297 - accuracy: 1.0000
# Epoch 93/100
# 4/4 - 0s - loss: 0.1258 - accuracy: 1.0000
# Epoch 94/100
# 4/4 - 0s - loss: 0.1220 - accuracy: 1.0000
# Epoch 95/100
# 4/4 - 0s - loss: 0.1209 - accuracy: 1.0000
# Epoch 96/100
# 4/4 - 0s - loss: 0.1143 - accuracy: 1.0000
# Epoch 97/100
# 4/4 - 0s - loss: 0.1089 - accuracy: 1.0000
# Epoch 98/100
# 4/4 - 0s - loss: 0.1078 - accuracy: 1.0000
# Epoch 99/100
# 4/4 - 0s - loss: 0.1041 - accuracy: 1.0000
# Epoch 100/100
# 4/4 - 0s - loss: 0.1007 - accuracy: 1.0000

# %%
model_loss, model_accuracy = deep_model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2/2 - 0s - loss: 0.1725 - accuracy: 0.9756
# Deep Neural Network - Loss: 0.17248497903347015, Accuracy: 0.9756097793579102

# %%
prediction = np.argmax(deep_model.predict(X_test_scaled), axis = -1)
predicted_labels = label_encoder.inverse_transform(prediction)
print(f"Predicted Labels: {predicted_labels[:5]}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted Labels: ['Burlington' 'Cumberland' 'Union' 'Camden' 'Morris']
# Actual Labels: ['Burlington', 'Cumberland', 'Union', 'Camden', 'Morris']

# %%
# Save the model
deep_model.save("NJ_deep_learning.h5")
